# %% [markdown]
# # Temperature Ablation：T = 5

# %% [markdown]
# **相似度差一點沒那麼重要**
# SimCLR → Temperature = 0.5 → 訓練 → Loss / kNN Accuracy → 作為比較基準

# %% [markdown]
# ## step1:Import + 基本設定

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.models import resnet18

import matplotlib.pyplot as plt
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Device:", device)
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# Device: cuda
# GPU: NVIDIA GeForce RTX 5060 Laptop GPU

# %% [markdown]
# ## step2:CIFAR-10 + SimCLR Augmentation

# %%
CIFAR10_MEAN = (0.4914, 0.4822, 0.4465)
CIFAR10_STD = (0.2470, 0.2435, 0.2616)

class SimCLRTransform:
    def __init__(self):
        self.transform = transforms.Compose([
            transforms.RandomResizedCrop(32, scale=(0.2, 1.0)),
            transforms.RandomHorizontalFlip(),
            transforms.RandomApply([
                transforms.ColorJitter(
                    brightness=0.4,
                    contrast=0.4,
                    saturation=0.4,
                    hue=0.1
                )
            ], p=0.8),
            transforms.RandomGrayscale(p=0.2),
            transforms.ToTensor(),
            transforms.Normalize(CIFAR10_MEAN, CIFAR10_STD)
        ])

    def __call__(self, image):
        return self.transform(image), self.transform(image)


train_dataset = datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=SimCLRTransform()
)

batch_size = 256

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,
    drop_last=True
)

print("Train:", len(train_dataset))
# Out:
# c:\Users\user\anaconda3\envs\summer\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Train: 50000

# %% [markdown]
# ## step3:kNN Evaluation Dataset

# %%
eval_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(CIFAR10_MEAN, CIFAR10_STD)
])

knn_train_dataset = datasets.CIFAR10(
    root="./data",
    train=True,
    download=False,
    transform=eval_transform
)

knn_test_dataset = datasets.CIFAR10(
    root="./data",
    train=False,
    download=False,
    transform=eval_transform
)

knn_train_loader = DataLoader(
    knn_train_dataset,
    batch_size=256,
    shuffle=False,
    num_workers=0
)

knn_test_loader = DataLoader(
    knn_test_dataset,
    batch_size=256,
    shuffle=False,
    num_workers=0
)

print("kNN train:", len(knn_train_dataset))
print("kNN test:", len(knn_test_dataset))
# Out:
# kNN train: 50000
# kNN test: 10000

# %% [markdown]
# ## step4:SimCLR Model

# %%
class SimCLRModel(nn.Module):
    def __init__(self):
        super().__init__()

        self.backbone = resnet18(weights=None)

        self.backbone.conv1 = nn.Conv2d(
            3,
            64,
            kernel_size=3,
            stride=1,
            padding=1,
            bias=False
        )

        self.backbone.maxpool = nn.Identity()
        self.backbone.fc = nn.Identity()

        self.projector = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 128)
        )

    def forward(self, x):
        h = self.backbone(x)
        z = self.projector(h)
        return h, z

# %% [markdown]
# ## step5:NT-Xent Loss

# %%
def nt_xent_loss(z1, z2, temperature=0.1):
    N = z1.size(0)

    z = torch.cat([z1, z2], dim=0)
    z = F.normalize(z, dim=1)

    similarity = torch.matmul(z, z.T) / temperature

    mask = torch.eye(
        2 * N,
        dtype=torch.bool,
        device=z.device
    )

    similarity.masked_fill_(mask, -float("inf"))

    labels = torch.arange(2 * N, device=z.device)
    labels = (labels + N) % (2 * N)

    loss = F.cross_entropy(similarity, labels)

    return loss

# %% [markdown]
# ## step6:kNN Monitor

# %%
@torch.no_grad()
def knn_monitor(model, train_loader, test_loader, device, k=20):
    model.eval()

    feature_bank = []
    label_bank = []

    for images, labels in train_loader:
        images = images.to(device)

        h, _ = model(images)
        h = F.normalize(h, dim=1)

        feature_bank.append(h)
        label_bank.append(labels)

    feature_bank = torch.cat(feature_bank, dim=0)
    label_bank = torch.cat(label_bank, dim=0).to(device)

    correct = 0
    total = 0

    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        h, _ = model(images)
        h = F.normalize(h, dim=1)

        similarity = torch.mm(h, feature_bank.T)

        _, indices = similarity.topk(k=k, dim=1)
        neighbor_labels = label_bank[indices]

        predictions = torch.mode(
            neighbor_labels,
            dim=1
        ).values

        correct += (predictions == labels).sum().item()
        total += labels.size(0)

    accuracy = 100.0 * correct / total

    model.train()

    return accuracy

# %% [markdown]
# ## step7:正式訓練 T = 5

# %%
num_epochs = 200

temperature = 5
learning_rate = 3e-4
weight_decay = 1e-6

knn_interval = 5
k = 20

model = SimCLRModel().to(device)

optimizer = optim.Adam(
    model.parameters(),
    lr=learning_rate,
    weight_decay=weight_decay
)

loss_history = []
knn_epochs = []
knn_history = []

training_start = time.time()

for epoch in range(1, num_epochs + 1):

    model.train()

    total_loss = 0.0
    epoch_start = time.time()

    for (x1, x2), _ in train_loader:

        x1 = x1.to(device)
        x2 = x2.to(device)

        optimizer.zero_grad()

        _, z1 = model(x1)
        _, z2 = model(x2)

        loss = nt_xent_loss(
            z1,
            z2,
            temperature=temperature
        )

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / len(train_loader)
    loss_history.append(avg_loss)

    epoch_time = time.time() - epoch_start

    print(
        f"Epoch [{epoch:3d}/{num_epochs}] "
        f"| Loss: {avg_loss:.4f} "
        f"| Time: {epoch_time:.1f}s",
        end=""
    )

    if epoch % knn_interval == 0:

        knn_start = time.time()

        knn_acc = knn_monitor(
            model,
            knn_train_loader,
            knn_test_loader,
            device,
            k=k
        )

        knn_time = time.time() - knn_start

        knn_epochs.append(epoch)
        knn_history.append(knn_acc)

        print(
            f" | kNN Accuracy: {knn_acc:.2f}% "
            f"| kNN Time: {knn_time:.1f}s"
        )

        torch.save(
            {
                "epoch": epoch,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "loss_history": loss_history,
                "knn_epochs": knn_epochs,
                "knn_history": knn_history,
                "temperature": temperature
            },
            "simclr_temp05_checkpoint.pth"
        )

    else:
        print()

torch.save(
    model.state_dict(),
    "simclr_temp5_final.pth"
)

total_time = time.time() - training_start

print("\n===== Temperature 5 Finished =====")
print(f"Total Training Time: {total_time / 3600:.2f} hours")
print(f"Final Loss: {loss_history[-1]:.4f}")
print(f"Final kNN Accuracy: {knn_history[-1]:.2f}%")
# Out:
# Epoch [  1/200] | Loss: 6.1147 | Time: 73.2s
# Epoch [  2/200] | Loss: 6.0977 | Time: 72.9s
# Epoch [  3/200] | Loss: 6.0900 | Time: 72.7s
# Epoch [  4/200] | Loss: 6.0845 | Time: 78.0s
# Epoch [  5/200] | Loss: 6.0803 | Time: 83.7s | kNN Accuracy: 44.85% | kNN Time: 9.8s
# Epoch [  6/200] | Loss: 6.0771 | Time: 83.0s
# Epoch [  7/200] | Loss: 6.0752 | Time: 84.3s
# Epoch [  8/200] | Loss: 6.0741 | Time: 84.8s
# Epoch [  9/200] | Loss: 6.0725 | Time: 83.9s
# Epoch [ 10/200] | Loss: 6.0716 | Time: 82.2s | kNN Accuracy: 50.06% | kNN Time: 9.6s
# Epoch [ 11/200] | Loss: 6.0704 | Time: 82.8s
# Epoch [ 12/200] | Loss: 6.0694 | Time: 82.7s
# Epoch [ 13/200] | Loss: 6.0693 | Time: 84.5s
# Epoch [ 14/200] | Loss: 6.0684 | Time: 81.7s
# Epoch [ 15/200] | Loss: 6.0676 | Time: 83.4s | kNN Accuracy: 53.55% | kNN Time: 9.7s
# Epoch [ 16/200] | Loss: 6.0669 | Time: 83.7s
# Epoch [ 17/200] | Loss: 6.0665 | Time: 82.7s
# Epoch [ 18/200] | Loss: 6.0659 | Time: 83.9s
# Epoch [ 19/200] | Loss: 6.0656 | Time: 82.1s
# Epoch [ 20/200] | Loss: 6.0652 | Time: 81.9s | kNN Accuracy: 56.37% | kNN Time: 9.5s
# Epoch [ 21/200] | Loss: 6.0651 | Time: 82.0s
# Epoch [ 22/200] | Loss: 6.0647 | Time: 82.7s
# Epoch [ 23/200] | Loss: 6.0645 | Time: 83.5s
# Epoch [ 24/200] | Loss: 6.0641 | Time: 82.9s
# Epoch [ 25/200] | Loss: 6.0639 | Time: 82.9s | kNN Accuracy: 57.97% | kNN Time: 9.4s
# Epoch [ 26/200] | Loss: 6.0637 | Time: 83.0s
# Epoch [ 27/200] | Loss: 6.0633 | Time: 83.0s
# Epoch [ 28/200] | Loss: 6.0633 | Time: 83.6s
# Epoch [ 29/200] | Loss: 6.0630 | Time: 83.5s
# Epoch [ 30/200] | Loss: 6.0626 | Time: 84.0s | kNN Accuracy: 59.58% | kNN Time: 9.5s
# Epoch [ 31/200] | Loss: 6.0624 | Time: 85.9s
# Epoch [ 32/200] | Loss: 6.0621 | Time: 82.4s
# Epoch [ 33/200] | Loss: 6.0623 | Time: 81.6s
# Epoch [ 34/200] | Loss: 6.0622 | Time: 81.5s
# Epoch [ 35/200] | Loss: 6.0621 | Time: 83.4s | kNN Accuracy: 61.28% | kNN Time: 9.7s
# Epoch [ 36/200] | Loss: 6.0616 | Time: 83.0s
# Epoch [ 37/200] | Loss: 6.0616 | Time: 82.6s
# Epoch [ 38/200] | Loss: 6.0614 | Time: 82.4s
# Epoch [ 39/200] | Loss: 6.0613 | Time: 82.2s
# Epoch [ 40/200] | Loss: 6.0610 | Time: 82.5s | kNN Accuracy: 62.18% | kNN Time: 9.4s
# Epoch [ 41/200] | Loss: 6.0610 | Time: 81.6s
# Epoch [ 42/200] | Loss: 6.0611 | Time: 81.6s
# Epoch [ 43/200] | Loss: 6.0608 | Time: 83.7s
# Epoch [ 44/200] | Loss: 6.0606 | Time: 83.7s
# Epoch [ 45/200] | Loss: 6.0608 | Time: 83.0s | kNN Accuracy: 62.53% | kNN Time: 9.6s
# Epoch [ 46/200] | Loss: 6.0606 | Time: 82.5s
# Epoch [ 47/200] | Loss: 6.0605 | Time: 83.2s
# Epoch [ 48/200] | Loss: 6.0605 | Time: 82.4s
# Epoch [ 49/200] | Loss: 6.0604 | Time: 82.1s
# Epoch [ 50/200] | Loss: 6.0602 | Time: 82.8s | kNN Accuracy: 64.11% | kNN Time: 10.0s
# Epoch [ 51/200] | Loss: 6.0598 | Time: 84.4s
# Epoch [ 52/200] | Loss: 6.0601 | Time: 82.9s
# Epoch [ 53/200] | Loss: 6.0598 | Time: 82.4s
# Epoch [ 54/200] | Loss: 6.0601 | Time: 82.4s
# Epoch [ 55/200] | Loss: 6.0597 | Time: 82.2s | kNN Accuracy: 63.96% | kNN Time: 9.9s
# Epoch [ 56/200] | Loss: 6.0596 | Time: 83.9s
# Epoch [ 57/200] | Loss: 6.0596 | Time: 82.3s
# Epoch [ 58/200] | Loss: 6.0594 | Time: 80.9s
# Epoch [ 59/200] | Loss: 6.0594 | Time: 82.4s
# Epoch [ 60/200] | Loss: 6.0592 | Time: 81.2s | kNN Accuracy: 65.15% | kNN Time: 9.8s
# Epoch [ 61/200] | Loss: 6.0591 | Time: 82.3s
# Epoch [ 62/200] | Loss: 6.0589 | Time: 82.3s
# Epoch [ 63/200] | Loss: 6.0591 | Time: 83.4s
# Epoch [ 64/200] | Loss: 6.0590 | Time: 83.0s
# Epoch [ 65/200] | Loss: 6.0589 | Time: 83.0s | kNN Accuracy: 66.03% | kNN Time: 9.7s
# Epoch [ 66/200] | Loss: 6.0588 | Time: 82.8s
# Epoch [ 67/200] | Loss: 6.0586 | Time: 82.2s
# Epoch [ 68/200] | Loss: 6.0589 | Time: 83.6s
# Epoch [ 69/200] | Loss: 6.0588 | Time: 83.2s
# Epoch [ 70/200] | Loss: 6.0587 | Time: 83.6s | kNN Accuracy: 65.89% | kNN Time: 9.7s
# Epoch [ 71/200] | Loss: 6.0586 | Time: 82.7s
# Epoch [ 72/200] | Loss: 6.0585 | Time: 82.2s
# Epoch [ 73/200] | Loss: 6.0582 | Time: 81.6s
# Epoch [ 74/200] | Loss: 6.0587 | Time: 83.5s
# Epoch [ 75/200] | Loss: 6.0587 | Time: 81.9s | kNN Accuracy: 67.04% | kNN Time: 9.5s
# Epoch [ 76/200] | Loss: 6.0580 | Time: 83.6s
# Epoch [ 77/200] | Loss: 6.0579 | Time: 83.3s
# Epoch [ 78/200] | Loss: 6.0584 | Time: 83.5s
# Epoch [ 79/200] | Loss: 6.0581 | Time: 82.9s
# Epoch [ 80/200] | Loss: 6.0581 | Time: 81.8s | kNN Accuracy: 67.62% | kNN Time: 9.6s
# Epoch [ 81/200] | Loss: 6.0580 | Time: 83.7s
# Epoch [ 82/200] | Loss: 6.0579 | Time: 88.3s
# Epoch [ 83/200] | Loss: 6.0578 | Time: 85.2s
# Epoch [ 84/200] | Loss: 6.0578 | Time: 82.7s
# Epoch [ 85/200] | Loss: 6.0576 | Time: 88.7s | kNN Accuracy: 68.15% | kNN Time: 10.2s
# Epoch [ 86/200] | Loss: 6.0579 | Time: 89.5s
# Epoch [ 87/200] | Loss: 6.0577 | Time: 82.9s
# Epoch [ 88/200] | Loss: 6.0576 | Time: 85.6s
# Epoch [ 89/200] | Loss: 6.0576 | Time: 87.0s
# Epoch [ 90/200] | Loss: 6.0575 | Time: 90.7s | kNN Accuracy: 68.66% | kNN Time: 9.8s
# Epoch [ 91/200] | Loss: 6.0573 | Time: 85.6s
# Epoch [ 92/200] | Loss: 6.0576 | Time: 84.3s
# Epoch [ 93/200] | Loss: 6.0570 | Time: 84.1s
# Epoch [ 94/200] | Loss: 6.0570 | Time: 87.4s
# Epoch [ 95/200] | Loss: 6.0571 | Time: 86.5s | kNN Accuracy: 69.58% | kNN Time: 9.9s
# Epoch [ 96/200] | Loss: 6.0570 | Time: 84.7s
# Epoch [ 97/200] | Loss: 6.0569 | Time: 87.8s
# Epoch [ 98/200] | Loss: 6.0568 | Time: 81.7s
# Epoch [ 99/200] | Loss: 6.0567 | Time: 83.1s
# Epoch [100/200] | Loss: 6.0568 | Time: 82.9s | kNN Accuracy: 70.35% | kNN Time: 9.7s
# Epoch [101/200] | Loss: 6.0566 | Time: 83.7s
# Epoch [102/200] | Loss: 6.0566 | Time: 83.5s
# Epoch [103/200] | Loss: 6.0565 | Time: 82.3s
# Epoch [104/200] | Loss: 6.0565 | Time: 81.6s
# Epoch [105/200] | Loss: 6.0567 | Time: 84.3s | kNN Accuracy: 71.28% | kNN Time: 9.9s
# Epoch [106/200] | Loss: 6.0568 | Time: 82.9s
# Epoch [107/200] | Loss: 6.0562 | Time: 87.2s
# Epoch [108/200] | Loss: 6.0564 | Time: 82.9s
# Epoch [109/200] | Loss: 6.0564 | Time: 85.7s
# Epoch [110/200] | Loss: 6.0562 | Time: 89.5s | kNN Accuracy: 71.65% | kNN Time: 11.7s
# Epoch [111/200] | Loss: 6.0561 | Time: 89.8s
# Epoch [112/200] | Loss: 6.0561 | Time: 86.3s
# Epoch [113/200] | Loss: 6.0562 | Time: 85.9s
# Epoch [114/200] | Loss: 6.0561 | Time: 85.2s
# Epoch [115/200] | Loss: 6.0558 | Time: 85.0s | kNN Accuracy: 71.92% | kNN Time: 9.7s
# Epoch [116/200] | Loss: 6.0560 | Time: 88.0s
# Epoch [117/200] | Loss: 6.0559 | Time: 86.1s
# Epoch [118/200] | Loss: 6.0556 | Time: 89.3s
# Epoch [119/200] | Loss: 6.0560 | Time: 86.6s
# Epoch [120/200] | Loss: 6.0560 | Time: 82.6s | kNN Accuracy: 72.17% | kNN Time: 9.5s
# Epoch [121/200] | Loss: 6.0558 | Time: 85.2s
# Epoch [122/200] | Loss: 6.0558 | Time: 79.3s
# Epoch [123/200] | Loss: 6.0559 | Time: 90.9s
# Epoch [124/200] | Loss: 6.0556 | Time: 88.2s
# Epoch [125/200] | Loss: 6.0558 | Time: 86.8s | kNN Accuracy: 73.34% | kNN Time: 10.6s
# Epoch [126/200] | Loss: 6.0554 | Time: 89.2s
# Epoch [127/200] | Loss: 6.0555 | Time: 88.9s
# Epoch [128/200] | Loss: 6.0558 | Time: 85.4s
# Epoch [129/200] | Loss: 6.0556 | Time: 86.2s
# Epoch [130/200] | Loss: 6.0555 | Time: 87.2s | kNN Accuracy: 73.34% | kNN Time: 10.8s
# Epoch [131/200] | Loss: 6.0554 | Time: 80.7s
# Epoch [132/200] | Loss: 6.0552 | Time: 80.0s
# Epoch [133/200] | Loss: 6.0555 | Time: 88.3s
# Epoch [134/200] | Loss: 6.0552 | Time: 85.4s
# Epoch [135/200] | Loss: 6.0553 | Time: 88.2s | kNN Accuracy: 73.93% | kNN Time: 10.7s
# Epoch [136/200] | Loss: 6.0552 | Time: 84.6s
# Epoch [137/200] | Loss: 6.0555 | Time: 78.4s
# Epoch [138/200] | Loss: 6.0551 | Time: 78.8s
# Epoch [139/200] | Loss: 6.0552 | Time: 79.4s
# Epoch [140/200] | Loss: 6.0549 | Time: 79.8s | kNN Accuracy: 74.25% | kNN Time: 10.0s
# Epoch [141/200] | Loss: 6.0552 | Time: 77.6s
# Epoch [142/200] | Loss: 6.0552 | Time: 83.8s
# Epoch [143/200] | Loss: 6.0552 | Time: 77.3s
# Epoch [144/200] | Loss: 6.0551 | Time: 73.6s
# Epoch [145/200] | Loss: 6.0552 | Time: 73.5s | kNN Accuracy: 74.70% | kNN Time: 9.3s
# Epoch [146/200] | Loss: 6.0548 | Time: 73.6s
# Epoch [147/200] | Loss: 6.0551 | Time: 73.4s
# Epoch [148/200] | Loss: 6.0550 | Time: 73.2s
# Epoch [149/200] | Loss: 6.0550 | Time: 73.4s
# Epoch [150/200] | Loss: 6.0549 | Time: 73.3s | kNN Accuracy: 74.88% | kNN Time: 9.2s
# Epoch [151/200] | Loss: 6.0551 | Time: 73.1s
# Epoch [152/200] | Loss: 6.0549 | Time: 73.3s
# Epoch [153/200] | Loss: 6.0549 | Time: 73.1s
# Epoch [154/200] | Loss: 6.0548 | Time: 73.2s
# Epoch [155/200] | Loss: 6.0547 | Time: 73.2s | kNN Accuracy: 75.48% | kNN Time: 9.2s
# Epoch [156/200] | Loss: 6.0549 | Time: 73.2s
# Epoch [157/200] | Loss: 6.0548 | Time: 73.1s
# Epoch [158/200] | Loss: 6.0546 | Time: 72.9s
# Epoch [159/200] | Loss: 6.0544 | Time: 73.0s
# Epoch [160/200] | Loss: 6.0547 | Time: 72.9s | kNN Accuracy: 75.32% | kNN Time: 9.2s
# Epoch [161/200] | Loss: 6.0547 | Time: 73.0s
# Epoch [162/200] | Loss: 6.0548 | Time: 72.7s
# Epoch [163/200] | Loss: 6.0546 | Time: 72.8s
# Epoch [164/200] | Loss: 6.0547 | Time: 72.5s
# Epoch [165/200] | Loss: 6.0545 | Time: 72.7s | kNN Accuracy: 76.17% | kNN Time: 9.2s
# Epoch [166/200] | Loss: 6.0543 | Time: 72.9s
# Epoch [167/200] | Loss: 6.0543 | Time: 72.4s
# Epoch [168/200] | Loss: 6.0544 | Time: 72.7s
# Epoch [169/200] | Loss: 6.0545 | Time: 72.6s
# Epoch [170/200] | Loss: 6.0544 | Time: 73.8s | kNN Accuracy: 76.17% | kNN Time: 9.3s
# Epoch [171/200] | Loss: 6.0544 | Time: 72.7s
# Epoch [172/200] | Loss: 6.0545 | Time: 72.6s
# Epoch [173/200] | Loss: 6.0545 | Time: 72.5s
# Epoch [174/200] | Loss: 6.0542 | Time: 72.8s
# Epoch [175/200] | Loss: 6.0542 | Time: 72.7s | kNN Accuracy: 76.68% | kNN Time: 9.2s
# Epoch [176/200] | Loss: 6.0543 | Time: 72.9s
# Epoch [177/200] | Loss: 6.0541 | Time: 72.7s
# Epoch [178/200] | Loss: 6.0546 | Time: 72.7s
# Epoch [179/200] | Loss: 6.0542 | Time: 72.8s
# Epoch [180/200] | Loss: 6.0542 | Time: 72.6s | kNN Accuracy: 77.58% | kNN Time: 9.2s
# Epoch [181/200] | Loss: 6.0542 | Time: 72.4s
# Epoch [182/200] | Loss: 6.0541 | Time: 72.6s
# Epoch [183/200] | Loss: 6.0542 | Time: 72.4s
# Epoch [184/200] | Loss: 6.0539 | Time: 72.6s
# Epoch [185/200] | Loss: 6.0541 | Time: 72.7s | kNN Accuracy: 76.86% | kNN Time: 9.2s
# Epoch [186/200] | Loss: 6.0540 | Time: 72.7s
# Epoch [187/200] | Loss: 6.0540 | Time: 72.6s
# Epoch [188/200] | Loss: 6.0540 | Time: 72.4s
# Epoch [189/200] | Loss: 6.0541 | Time: 72.6s
# Epoch [190/200] | Loss: 6.0536 | Time: 72.5s | kNN Accuracy: 77.75% | kNN Time: 9.2s
# Epoch [191/200] | Loss: 6.0542 | Time: 72.8s
# Epoch [192/200] | Loss: 6.0541 | Time: 72.5s
# Epoch [193/200] | Loss: 6.0539 | Time: 72.8s
# Epoch [194/200] | Loss: 6.0540 | Time: 72.7s
# Epoch [195/200] | Loss: 6.0537 | Time: 72.8s | kNN Accuracy: 77.83% | kNN Time: 9.2s
# Epoch [196/200] | Loss: 6.0539 | Time: 72.7s
# Epoch [197/200] | Loss: 6.0538 | Time: 72.8s
# Epoch [198/200] | Loss: 6.0537 | Time: 72.5s
# Epoch [199/200] | Loss: 6.0538 | Time: 76.0s
# Epoch [200/200] | Loss: 6.0536 | Time: 77.1s | kNN Accuracy: 77.94% | kNN Time: 9.4s
#
# ===== Temperature 5 Finished =====
# Total Training Time: 4.58 hours
# Final Loss: 6.0536
# Final kNN Accuracy: 77.94%

# %% [markdown]
# ## step8:畫圖

# %%
# Loss Curve
epochs = range(1, len(loss_history) + 1)

plt.figure(figsize=(8, 5))
plt.plot(epochs, loss_history, linewidth=2)

plt.xlabel("Epoch")
plt.ylabel("NT-Xent Loss")
plt.title("SimCLR Training Loss (Temperature = 5)")
plt.grid(True)

plt.tight_layout()
plt.savefig("simclr_temp5_loss_curve.png", dpi=300)
plt.show()


# kNN Accuracy Curve
plt.figure(figsize=(8, 5))
plt.plot(
    knn_epochs,
    knn_history,
    marker="o",
    linewidth=2
)

plt.xlabel("Epoch")
plt.ylabel("kNN Accuracy (%)")
plt.title("SimCLR kNN Accuracy (Temperature = 5)")
plt.grid(True)

plt.tight_layout()
plt.savefig("simclr_temp5_knn_curve.png", dpi=300)
plt.show()
